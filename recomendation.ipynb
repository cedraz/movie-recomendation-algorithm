# %%
import numpy as np
import pandas as pd
import json

# %%
filmes = pd.read_csv('./tmdb_5000_movies.csv')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
filmes.drop_duplicates(subset=['original_title'], keep='first', inplace=True)

filmes['overview'] = filmes['overview'].fillna('')
filmes['genres'] = filmes['genres'].fillna('')
filmes['tagline'] = filmes['tagline'].fillna('')

def json_to_text(json_string):
    try:
        json_dict = json.loads(json_string)
        return ' '.join([x['name'] for x in json_dict])
    except json.JSONDecodeError:
        return ''

# %%
filmes['keywords'] = filmes['keywords'].apply(json_to_text)

# %%
filmes['genres'] = filmes['genres'].apply(json_to_text)
display(filmes.head(20))
# Out:
#        budget genres                                           homepage  \
# 0   237000000                               http://www.avatarmovie.com/
# 1   300000000              http://disney.go.com/disneypictures/pirates/
# 2   245000000               http://www.sonypictures.com/movies/spectre/
# 3   250000000                        http://www.thedarkknightrises.com/
# 4   260000000                      http://movies.disney.com/john-carter
# 5   258000000           http://www.sonypictures.com/movies/spider-man3/
# 6   260000000              http://disney.go.com/disneypictures/tangled/
# 7   280000000         http://marvel.com/movies/movie/193/avengers_ag...
# 8   250000000         http://harrypotter.warnerbros.com/harrypottera...
# 9   250000000              http://www.batmanvsupermandawnofjustice.com/
# 10  270000000                                   http://www.superman.com
# 11  200000000         http://www.mgm.com/view/movie/234/Quantum-of-S...
# 12  200000000              http://disney.go.com/disneypictures/pirates/
# 13  255000000                     http://disney.go.com/the-lone-ranger/
# 14  225000000                                http://www.manofsteel.com/
# 15  225000000                                                       NaN
# 16  220000000                         http://marvel.com/avengers_movie/
# 17  380000000         http://disney.go.com/pirates/index-on-stranger...
# 18  225000000           http://www.sonypictures.com/movies/meninblack3/
# 19  250000000                                 http://www.thehobbit.com/
#
#         id                                           keywords  \
# 0    19995  culture clash future space war space colony so...
# 1      285  ocean drug abuse exotic island east india trad...
# 2   206647  spy based on novel secret agent sequel mi6 bri...
# 3    49026  dc comics crime fighter terrorist secret ident...
# 4    49529  based on novel mars medallion space travel pri...
# 5      559  dual identity amnesia sandstorm love of one's ...
# 6    38757  hostage magic horse fairy tale musical princes...
# 7    99861  marvel comic sequel superhero based on comic b...
# 8      767  witch magic broom school of witchcraft wizardr...
# 9   209112  dc comics vigilante superhero based on comic b...
# 10    1452  saving the world dc comics invulnerability seq...
# 11   10764  killing undercover secret agent british secret...
# 12      58  witch fortune teller bondage exotic island mon...
# 13   57201  texas horse survivor texas ranger partner outl...
# 14   49521  saving the world dc comics superhero based on ...
# 15    2454  based on novel fictional place brother sister ...
# 16   24428  new york shield marvel comic superhero based o...
# 17    1865  sea captain mutiny sword prime minister sailin...
# 18   41154  time travel time machine alien fictional gover...
# 19  122917  corruption elves dwarves orcs middle-earth (to...
#
#    original_language                               original_title  \
# 0                 en                                       Avatar
# 1                 en     Pirates of the Caribbean: At World's End
# 2                 en                                      Spectre
# 3                 en                        The Dark Knight Rises
# 4                 en                                  John Carter
# 5                 en                                 Spider-Man 3
# 6                 en                                      Tangled
# 7                 en                      Avengers: Age of Ultron
# 8                 en       Harry Potter and the Half-Blood Prince
# 9                 en           Batman v Superman: Dawn of Justice
# 10                en                             Superman Returns
# 11                en                            Quantum of Solace
# 12                en   Pirates of the Caribbean: Dead Man's Chest
# 13                en                              The Lone Ranger
# 14                en                                 Man of Steel
# 15                en     The Chronicles of Narnia: Prince Caspian
# 16                en                                 The Avengers
# 17                en  Pirates of the Caribbean: On Stranger Tides
# 18                en                               Men in Black 3
# 19                en    The Hobbit: The Battle of the Five Armies
#
#                                              overview  popularity  \
# 0   In the 22nd century, a paraplegic Marine is di...  150.437577
# 1   Captain Barbossa, long believed to be dead, ha...  139.082615
# 2   A cryptic message from Bond’s past sends him o...  107.376788
# 3   Following the death of District Attorney Harve...  112.312950
# 4   John Carter is a war-weary, former military ca...   43.926995
# 5   The seemingly invincible Spider-Man goes up ag...  115.699814
# 6   When the kingdom's most wanted-and most charmi...   48.681969
# 7   When Tony Stark tries to jumpstart a dormant p...  134.279229
# 8   As Harry begins his sixth year at Hogwarts, he...   98.885637
# 9   Fearing the actions of a god-like Super Hero l...  155.790452
# 10  Superman returns to discover his 5-year absenc...   57.925623
# 11  Quantum of Solace continues the adventures of ...  107.928811
# 12  Captain Jack Sparrow works his way out of a bl...  145.847379
# 13  The Texas Rangers chase down a gang of outlaws...   49.046956
# 14  A young boy learns that he has extraordinary p...   99.398009
# 15  One year after their incredible adventures in ...   53.978602
# 16  When an unexpected enemy emerges and threatens...  144.448633
# 17  Captain Jack Sparrow crosses paths with a woma...  135.413856
# 18  Agents J (Will Smith) and K (Tommy Lee Jones) ...   52.035179
# 19  Immediately after the events of The Desolation...  120.965743
#
#                                  production_companies  ... release_date  \
# 0   [{"name": "Ingenious Film Partners", "id": 289...  ...   2009-12-10
# 1   [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   2007-05-19
# 2   [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   2015-10-26
# 3   [{"name": "Legendary Pictures", "id": 923}, {"...  ...   2012-07-16
# 4         [{"name": "Walt Disney Pictures", "id": 2}]  ...   2012-03-07
# 5   [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   2007-05-01
# 6   [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   2010-11-24
# 7   [{"name": "Marvel Studios", "id": 420}, {"name...  ...   2015-04-22
# 8   [{"name": "Warner Bros.", "id": 6194}, {"name"...  ...   2009-07-07
# 9   [{"name": "DC Comics", "id": 429}, {"name": "A...  ...   2016-03-23
# 10  [{"name": "DC Comics", "id": 429}, {"name": "L...  ...   2006-06-28
# 11          [{"name": "Eon Productions", "id": 7576}]  ...   2008-10-30
# 12  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   2006-06-20
# 13  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   2013-07-03
# 14  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   2013-06-12
# 15  [{"name": "Walt Disney", "id": 5888}, {"name":...  ...   2008-05-15
# 16  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...   2012-04-25
# 17  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   2011-05-14
# 18  [{"name": "Amblin Entertainment", "id": 56}, {...  ...   2012-05-23
# 19  [{"name": "WingNut Films", "id": 11}, {"name":...  ...   2014-12-10
#
#        revenue  runtime                                   spoken_languages  \
# 0   2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1    961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2    880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3   1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4    284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# 5    890871626    139.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 6    591794936    100.0           [{"iso_639_1": "en", "name": "English"}]
# 7   1405403694    141.0           [{"iso_639_1": "en", "name": "English"}]
# 8    933959197    153.0           [{"iso_639_1": "en", "name": "English"}]
# 9    873260194    151.0           [{"iso_639_1": "en", "name": "English"}]
# 10   391081192    154.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 11   586090727    106.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 12  1065659812    151.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 13    89289910    149.0           [{"iso_639_1": "en", "name": "English"}]
# 14   662845518    143.0           [{"iso_639_1": "en", "name": "English"}]
# 15   419651413    150.0           [{"iso_639_1": "en", "name": "English"}]
# 16  1519557910    143.0           [{"iso_639_1": "en", "name": "English"}]
# 17  1045713802    136.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 18   624026776    106.0           [{"iso_639_1": "en", "name": "English"}]
# 19   956019788    144.0           [{"iso_639_1": "en", "name": "English"}]
#
#       status                                            tagline  \
# 0   Released                        Enter the World of Pandora.
# 1   Released     At the end of the world, the adventure begins.
# 2   Released                              A Plan No One Escapes
# 3   Released                                    The Legend Ends
# 4   Released               Lost in our world, found in another.
# 5   Released                                 The battle within.
# 6   Released           They're taking adventure to new lengths.
# 7   Released                                A New Age Has Come.
# 8   Released                              Dark Secrets Revealed
# 9   Released                                 Justice or revenge
# 10  Released
# 11  Released      For love, for hate, for justice, for revenge.
# 12  Released                                      Jack is back!
# 13  Released                            Never Take Off the Mask
# 14  Released               You will believe that a man can fly.
# 15  Released                               Hope has a new face.
# 16  Released                            Some assembly required.
# 17  Released                        Live Forever Or Die Trying.
# 18  Released                          They are back... in time.
# 19  Released  Witness the defining chapter of the Middle-Ear...
#
#                                           title vote_average  vote_count  \
# 0                                        Avatar          7.2       11800
# 1      Pirates of the Caribbean: At World's End          6.9        4500
# 2                                       Spectre          6.3        4466
# 3                         The Dark Knight Rises          7.6        9106
# 4                                   John Carter          6.1        2124
# 5                                  Spider-Man 3          5.9        3576
# 6                                       Tangled          7.4        3330
# 7                       Avengers: Age of Ultron          7.3        6767
# 8        Harry Potter and the Half-Blood Prince          7.4        5293
# 9            Batman v Superman: Dawn of Justice          5.7        7004
# 10                             Superman Returns          5.4        1400
# 11                            Quantum of Solace          6.1        2965
# 12   Pirates of the Caribbean: Dead Man's Chest          7.0        5246
# 13                              The Lone Ranger          5.9        2311
# 14                                 Man of Steel          6.5        6359
# 15     The Chronicles of Narnia: Prince Caspian          6.3        1630
# 16                                 The Avengers          7.4       11776
# 17  Pirates of the Caribbean: On Stranger Tides          6.4        4948
# 18                               Men in Black 3          6.2        4160
# 19    The Hobbit: The Battle of the Five Armies          7.1        4760
#
#                                                 infos
# 0   Enter the World of Pandora. In the 22nd centur...
# 1   At the end of the world, the adventure begins....
# 2   A Plan No One Escapes A cryptic message from B...
# 3   The Legend Ends Following the death of Distric...
# 4   Lost in our world, found in another. John Cart...
# 5   The battle within. The seemingly invincible Sp...
# 6   They're taking adventure to new lengths. When ...
# 7   A New Age Has Come. When Tony Stark tries to j...
# 8   Dark Secrets Revealed As Harry begins his sixt...
# 9   Justice or revenge Fearing the actions of a go...
# 10   Superman returns to discover his 5-year absen...
# 11  For love, for hate, for justice, for revenge. ...
# 12  Jack is back! Captain Jack Sparrow works his w...
# 13  Never Take Off the Mask The Texas Rangers chas...
# 14  You will believe that a man can fly. A young b...
# 15  Hope has a new face. One year after their incr...
# 16  Some assembly required. When an unexpected ene...
# 17  Live Forever Or Die Trying. Captain Jack Sparr...
# 18  They are back... in time. Agents J (Will Smith...
# 19  Witness the defining chapter of the Middle-Ear...
#
# [20 rows x 21 columns]

# %%
# pd.set_option('display.max_colwidth', 10000)

#display(filmes['keywords'])

filmes['infos'] = filmes['tagline'] + ' ' + filmes['overview'] + ' ' + filmes['genres'] + ' ' + filmes['keywords']

#display(filmes['infos'])

# %%
import difflib

def filme_mais_semelhante(nome_filme):
    semelhanca = difflib.get_close_matches(nome_filme, filmes['original_title'].tolist(), n=1, cutoff=0.6)
    if semelhanca:
        return semelhanca[0]
    else:
        return "Nenhum filme encontrado."

# Exemplo de uso
lista_filmes = ["O Poderoso Chefão", "Star Wars", "Matrix", "Senhor dos Anéis", "Jurassic Park"]
nome_digitado = input("Digite o nome do filme que você procura: ")

filme_encontrado = filme_mais_semelhante(nome_digitado)
print("Filme mais semelhante encontrado:", filme_encontrado)
# Out:
# Filme mais semelhante encontrado: Nenhum filme encontrado.

# %%
vec = TfidfVectorizer(stop_words='english')
Tfidf = vec.fit_transform(filmes['infos'].apply(lambda x: np.str_(x)))

cosine_sim = cosine_similarity(Tfidf)

sim_filmes = pd.DataFrame(cosine_sim, columns=filmes['original_title'], index=filmes['original_title'])

recommendations = pd.DataFrame(sim_filmes['Thor'].sort_values(ascending=False))

display(recommendations.head(20))
# Out:
#                                          Thor
# original_title
# Thor                                 1.000000
# Thor: The Dark World                 0.513994
# The Avengers                         0.215422
# Captain America: Civil War           0.196928
# Iron Man 2                           0.193920
# Avengers: Age of Ultron              0.191436
# Ant-Man                              0.174812
# Iron Man 3                           0.173517
# Captain America: The First Avenger   0.172039
# Iron Man                             0.165530
# Fantastic Four                       0.163414
# Guardians of the Galaxy              0.163163
# Captain America: The Winter Soldier  0.159104
# The Wolverine                        0.154112
# X-Men                                0.150989
# X-Men: Apocalypse                    0.148363
# X-Men: The Last Stand                0.140971
# The Incredible Hulk                  0.140082
# Man of Steel                         0.137342
# X-Men: Days of Future Past           0.131414
